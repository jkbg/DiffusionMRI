# %%
from utils.image_helpers import plot_image_grid, get_images

# %%
images = get_images('data/imagenet_v2_top_images', max_amount=20)
# Out:
# Number of Images: 10000

# %%
plot = plot_image_grid(images, nrows=5)
